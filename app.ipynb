# %%
# app.py

import plotly.graph_objects as go
from dash import Dash, dcc, html
from simulation import run_simulation
import networkx as nx  # For network visualizations

def visualize_blockchain(blockchain):
    G = nx.DiGraph()
    labels = {}

    # Add nodes and edges
    for block in blockchain.chain:
        index = block.index
        G.add_node(index)
        labels[index] = f"Block {index}\nHash: {block.hash()[:6]}..."
        if index > 0:
            G.add_edge(index - 1, index)

    # Layout
    pos = nx.spring_layout(G)

    # Edges
    edge_x = []
    edge_y = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=2, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Nodes
    node_x = []
    node_y = []
    node_text = []
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(labels[node])

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers+text',
        text=node_text,
        textposition="bottom center",
        hoverinfo='text',
        marker=dict(
            color='skyblue',
            size=50,
            line_width=2))

    # Figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title='Blockchain Structure',
                        showlegend=False,
                        hovermode='closest'))
    return fig

def visualize_entity_network(products):
    G = nx.MultiDiGraph()
    for product in products.values():
        history = product.get_history()
        for i in range(len(history) - 1):
            source = history[i]['updated_by']
            target = history[i+1]['updated_by']
            G.add_edge(source, target, product=product.product_id)

    pos = nx.spring_layout(G)

    # Edges
    edge_traces = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_traces.append(go.Scatter(
            x=[x0, x1, None], y=[y0, y1, None],
            line=dict(width=1, color='gray'),
            hoverinfo='text',
            mode='lines',
            text=f"Product: {edge[2]['product']}"))

    # Nodes
    node_x = []
    node_y = []
    node_text = []
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(node)

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers+text',
        text=node_text,
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            color='lightgreen',
            size=10,
            line_width=2))

    # Figure
    fig = go.Figure(data=edge_traces + [node_trace],
                    layout=go.Layout(
                        title='Network of Entities',
                        showlegend=False,
                        hovermode='closest'))
    return fig

def visualize_product_flow(products):
    sources = []
    targets = []
    values = []
    label_list = []

    for product in products.values():
        history = product.get_history()
        for i in range(len(history) - 1):
            source = history[i]['updated_by']
            target = history[i+1]['updated_by']
            if source not in label_list:
                label_list.append(source)
            if target not in label_list:
                label_list.append(target)
            sources.append(label_list.index(source))
            targets.append(label_list.index(target))
            values.append(1)

    fig = go.Figure(data=[go.Sankey(
        node=dict(
            pad=15,
            thickness=20,
            label=label_list,
            color="blue"),
        link=dict(
            source=sources,
            target=targets,
            value=values,
            color="lightblue"))])

    fig.update_layout(title_text="Product Flow Through Entities", font_size=10)
    return fig

# Run the simulation and get data
scm = run_simulation()
products = scm.products
blockchain = scm.blockchain

# Initialize the Dash app
app = Dash(__name__)

# Define the layout with tabs
app.layout = html.Div([
    html.H1("Supply Chain Simulation Dashboard"),
    dcc.Tabs([
        dcc.Tab(label='Product Flow', children=[
            dcc.Graph(figure=visualize_product_flow(products))
        ]),
        dcc.Tab(label='Blockchain Structure', children=[
            dcc.Graph(figure=visualize_blockchain(blockchain))
        ]),
        dcc.Tab(label='Network of Entities', children=[
            dcc.Graph(figure=visualize_entity_network(products))
        ])
    ])
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Product created: PROD001 at Phoenix by SupplierB at 2024-11-26 23:57:57
# Product PROD001 status updated to 'Manufactured' by ManufacturerA at 2024-11-27 06:57:57
# Product PROD001 status updated to 'In Transit' by LogisticsB at 2024-11-27 20:57:57
# Product PROD001 status updated to 'Available for Sale' by RetailerA at 2024-11-29 22:57:57
# Product PROD001 status updated to 'Purchased' by ConsumerB at 2024-12-01 23:57:57
# Product created: PROD002 at Phoenix by SupplierA at 2024-12-02 10:57:57
# Product PROD002 status updated to 'Manufactured' by ManufacturerA at 2024-12-02 18:57:57
# Product PROD002 status updated to 'In Transit' by LogisticsB at 2024-12-03 18:57:57
# Product PROD002 status updated to 'Available for Sale' by RetailerA at 2024-12-05 19:57:57
# Product PROD002 status updated to 'Purchased' by ConsumerA at 2024-12-06 21:57:57
# Product created: PROD003 at Los Angeles by SupplierB at 2024-12-07 17:57:57
# Product PROD003 status updated to 'Manufactured' by ManufacturerA at 2024-12-07 20:57:57
# Product PROD003 status updated to 'In Transit' by LogisticsA at 2024-12-08 22:57:57
# Product PROD003 status updated to 'Available for Sale' by RetailerA at 2024-12-11 18:57:57
# Product PROD003 status updated to 'Purchased' by ConsumerA at 2024-12-12 15:57:57
# Product created: PROD004 at Houston by SupplierA at 2024-12-13 15:57:57
# Product PROD004 status updated to 'Manufactured' by ManufacturerA at 2024-12-13 23:57:57
# Product PROD004 status updated to 'In Transit' by LogisticsB at 2024-12-15 04:57:57
# Product PROD004 status updated to 'Available for Sale' by RetailerB at 2024-12-17 15:57:57
# Product PROD004 status updated to 'Purchased' by ConsumerB at 2024-12-18 22:57:57
# Product created: PROD005 at Chicago by SupplierB at 2024-12-19 17:57:57
# Product PROD005 status updated to 'Manufactured' by ManufacturerA at 2024-12-20 05:57:57
# Product PROD005 status updated to 'In Transit' by LogisticsB at 2024-12-21 01:57:57
# Product PROD005 status updated to 'Available for Sale' by RetailerA at 2024-12-23 03:57:57
# Product PROD005 status updated to 'Purchased' by ConsumerA at 2024-12-23 10:57:57
# Product created: PROD006 at Houston by SupplierA at 2024-12-24 07:57:57
# Product PROD006 status updated to 'Manufactured' by ManufacturerA at 2024-12-24 11:57:57
# Product PROD006 status updated to 'In Transit' by LogisticsA at 2024-12-25 14:57:57
# Product PROD006 status updated to 'Available for Sale' by RetailerB at 2024-12-26 20:57:57
# Product PROD006 status updated to 'Purchased' by ConsumerB at 2024-12-29 00:57:57
# Product created: PROD007 at New York by SupplierB at 2024-12-29 21:57:57
# Product PROD007 status updated to 'Manufactured' by ManufacturerA at 2024-12-30 06:57:57
# Product PROD007 status updated to 'In Transit' by LogisticsB at 2024-12-31 08:57:57
# Product PROD007 status updated to 'Available for Sale' by RetailerA at 2025-01-02 00:57:57
# Product PROD007 status updated to 'Purchased' by ConsumerB at 2025-01-03 06:57:57
# Product created: PROD008 at Houston by SupplierA at 2025-01-03 23:57:57
# Product PROD008 status updated to 'Manufactured' by ManufacturerB at 2025-01-04 00:57:57
# Product PROD008 status updated to 'In Transit' by LogisticsA at 2025-01-05 20:57:57
# Product PROD008 status updated to 'Available for Sale' by RetailerA at 2025-01-06 22:57:57
# Product PROD008 status updated to 'Purchased' by ConsumerA at 2025-01-09 19:57:57
# Product created: PROD009 at Los Angeles by SupplierB at 2025-01-10 11:57:57
# Product PROD009 status updated to 'Manufactured' by ManufacturerA at 2025-01-10 16:57:57
# Product PROD009 status updated to 'In Transit' by LogisticsB at 2025-01-11 16:57:57
# Product PROD009 status updated to 'Available for Sale' by RetailerB at 2025-01-14 04:57:57
# Product PROD009 status updated to 'Purchased' by ConsumerB at 2025-01-14 17:57:57
# Product created: PROD010 at Los Angeles by SupplierA at 2025-01-15 08:57:57
# Product PROD010 status updated to 'Manufactured' by ManufacturerA at 2025-01-15 18:57:57
# Product PROD010 status updated to 'In Transit' by LogisticsA at 2025-01-17 04:57:57
# Product PROD010 status updated to 'Available for Sale' by RetailerB at 2025-01-19 13:57:57
# Product PROD010 status updated to 'Purchased' by ConsumerA at 2025-01-21 04:57:57
# New block mined and added to the blockchain. Block index: 1
# New block mined and added to the blockchain. Block index: 2
# New block mined and added to the blockchain. Block index: 3
# New block mined and added to the blockchain. Block index: 4
# New block mined and added to the blockchain. Block index: 5
# New block mined and added to the blockchain. Block index: 6
# New block mined and added to the blockchain. Block index: 7
# New block mined and added to the blockchain. Block index: 8
# New block mined and added to the blockchain. Block index: 9
# New block mined and added to the blockchain. Block index: 10
# New block mined and added to the blockchain. Block index: 11
# New block mined and added to the blockchain. Block index: 12
# New block mined and added to the blockchain. Block index: 13
# New block mined and added to the blockchain. Block index: 14
# New block mined and added to the blockchain. Block index: 15
# New block mined and added to the blockchain. Block index: 16
# New block mined and added to the blockchain. Block index: 17
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
